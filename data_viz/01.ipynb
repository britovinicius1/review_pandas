# %%
import pandas as pd

# %%
df = pd.read_csv("canadian_immegration_data.csv")

# %%
df
# Out:
#             Country Continent              Region             DevName  1980  \
# 0       Afghanistan      Asia       Southern Asia  Developing regions    16
# 1           Albania    Europe     Southern Europe   Developed regions     1
# 2           Algeria    Africa     Northern Africa  Developing regions    80
# 3    American Samoa   Oceania           Polynesia  Developing regions     0
# 4           Andorra    Europe     Southern Europe   Developed regions     0
# ..              ...       ...                 ...                 ...   ...
# 190        Viet Nam      Asia  South-Eastern Asia  Developing regions  1191
# 191  Western Sahara    Africa     Northern Africa  Developing regions     0
# 192           Yemen      Asia        Western Asia  Developing regions     1
# 193          Zambia    Africa      Eastern Africa  Developing regions    11
# 194        Zimbabwe    Africa      Eastern Africa  Developing regions    72
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 39 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    195 non-null    str
#  1   Continent  195 non-null    str
#  2   Region     195 non-null    str
#  3   DevName    195 non-null    str
#  4   1980       195 non-null    int64
#  5   1981       195 non-null    int64
#  6   1982       195 non-null    int64
#  7   1983       195 non-null    int64
#  8   1984       195 non-null    int64
#  9   1985       195 non-null    int64
#  10  1986       195 non-null    int64
#  11  1987       195 non-null    int64
#  12  1988       195 non-null    int64
#  13  1989       195 non-null    int64
#  14  1990       195 non-null    int64
#  15  1991       195 non-null    int64
#  16  1992       195 non-null    int64
#  17  1993       195 non-null    int64
#  18  1994       195 non-null    int64
#  19  1995       195 non-null    int64
# ...

# %%
df.set_index("Country", inplace=True)

# %%
df
# Out:
#                Continent              Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia       Southern Asia  Developing regions    16    39
# Albania           Europe     Southern Europe   Developed regions     1     0
# Algeria           Africa     Northern Africa  Developing regions    80    67
# American Samoa   Oceania           Polynesia  Developing regions     0     1
# Andorra           Europe     Southern Europe   Developed regions     0     0
# ...                  ...                 ...                 ...   ...   ...
# Viet Nam            Asia  South-Eastern Asia  Developing regions  1191  1829
# Western Sahara    Africa     Northern Africa  Developing regions     0     0
# Yemen               Asia        Western Asia  Developing regions     1     2
# Zambia            Africa      Eastern Africa  Developing regions    11    17
# Zimbabwe          Africa      Eastern Africa  Developing regions    72   114
#
# ...

# %%
anos = list(map(str, range(1980, 2014)))

# %%
print(anos)
# Out:
# ['1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013']

# %%
df_brazil = df.loc['Brazil', anos]

# %%
df_brazil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brazil, dtype: int64

# %%
df_brazil_df = df_brazil.reset_index()
df_brazil_df.columns = ['ano', 'imigrantes']

# %%
df_brazil_df
# Out:
#      ano  imigrantes
# 0   1980         211
# 1   1981         220
# 2   1982         192
# 3   1983         139
# 4   1984         145
# 5   1985         130
# 6   1986         205
# 7   1987         244
# 8   1988         394
# 9   1989         650
# 10  1990         650
# 11  1991         877
# 12  1992        1066
# 13  1993         866
# 14  1994         566
# 15  1995         572
# 16  1996         586
# 17  1997         591
# 18  1998         531
# 19  1999         626
# 20  2000         845
# 21  2001         847
# 22  2002         745
# 23  2003         839
# 24  2004         917
# 25  2005         969
# 26  2006        1181
# 27  2007        1746
# 28  2008        2138
# 29  2009        2509
# 30  2010        2598
# 31  2011        1508
# 32  2012        1642
# 33  2013        1714

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,4))
plt.plot(df_brazil_df['ano'], df_brazil_df['imigrantes'])
colunas_anos_agregadas_x = ['1980', '1985', '1990', '1995', '2000', '2005', '2010']
eixo_y = [500,1000,1500,2000,2500,3000]

plt.xticks(colunas_anos_agregadas_x)
plt.yticks(eixo_y)
plt.xlabel('Ano')
plt.ylabel('Número de imigrantes')
plt.title('Imigração do Brasil para o Canada')

plt.show()

# %%
### Visualizando comparação

df_comparacao = df.loc[['Brazil', 'Argentina'], anos]

# %%
df_comparacao
# Out:
#            1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  \
# Country                                                                ...
# Brazil      211   220   192   139   145   130   205   244   394   650  ...
# Argentina   368   426   626   241   237   196   213   519   374   538  ...
#
#            2004  2005  2006  2007  2008  2009  2010  2011  2012  2013
# Country
# Brazil      917   969  1181  1746  2138  2509  2598  1508  1642  1714
# Argentina  1591  1153   847   620   540   467   459   278   263   282
#
# [2 rows x 34 columns]

# %%
df_comparacao = df_comparacao.T

# %%
df_comparacao.head(5)
# Out:
# Country  Brazil  Argentina
# 1980        211        368
# 1981        220        426
# 1982        192        626
# 1983        139        241
# 1984        145        237

# %%
plt.plot(df_comparacao['Brazil'],label = 'Brasil')
plt.plot(df_comparacao['Argentina'],label ='Argentina')
plt.title('Imigração do Brasil e Argentina para o Canadá')
plt.xlabel('Ano')
plt.ylabel('Número de imigrantes')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.legend()
plt.show()

# %%
#Fig -> Cria uma figura em branco
# Ax -> eixos da figura

fig, ax = plt.subplots(figsize=(8,4))
ax.plot(df_brazil_df['ano'], df_brazil_df['imigrantes'], lw=3, color='r')
#frequencia de 5 em 5
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.set_title('Dados de imigração Brasil para o Canada\n1980 a 2013', fontsize=18, loc='left')
ax.set_xlabel('Ano', fontsize=14)
ax.set_ylabel('Número de imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
# plt.grid(linestyle='--')
plt.show()

# %%
##Axs - > pq terá subplots, por isso o s
#grafico um ao lado do outro 1 linha e duas colunas, dois graficos
#figsize -> largura dps altura

fig, axs = plt.subplots(1, 2, figsize=(15,5))
#pegando o primeiro grafico o 0
axs[0].plot(df_brazil_df['ano'], df_brazil_df['imigrantes'], color='red', linestyle='--', alpha=0.5 )
axs[0].set_title('Imigração do Brasil para o canada\n1980 a 2013', fontsize=18)
axs[0].set_xlabel('Ano', fontsize=14)
axs[0].set_ylabel('Número de imigrantes', fontsize=14)
axs[]
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5))
axs[0].grid()

#grafico 2

#interpretação grafico 2 -> dois traços valor minimo e máximo
#valor minimo +-100
#valor maximo entre 1500 e 2000
#caixinha do bloxplot
#em 25% os dados foram em torno de 400
#em 50% os dados foram +- 700
#em 75% dos anos a imigração foi em torno de1000
#os pontinhos são outliers

axs[1].boxplot(df_brazil_df['imigrantes'])
axs[1].set_title('Boxplot da imigração do Brasil para o Canadá\n1980 a 2013', fontsize='18')
axs[1].set_xlabel('Brasil')
axs[1].set_ylabel('Número de imigrantes')
axs[1].grid()

plt.show()

# %%
##pra confirmar as estatisticas

df_brazil_df.describe()
# Out:
#         imigrantes
# count    34.000000
# mean    872.323529
# std     663.401232
# min     130.000000
# 25%     428.250000
# 50%     697.500000
# 75%    1041.750000
# max    2598.000000

# %%
fig, axs = plt.subplots(2,2, figsize=(10,6))

#espaçamento horizontal e w controla vertical

fig.subplots_adjust(hspace=0.5, wspace=0.3)

fig.suptitle('Imigração dos quatro maiores paines da América do Sul para o Canadá\n1980 a 2013')

axs[0,0].plot(df.loc['Brazil', anos])
axs[0,0].set_title('Brasil')


axs[0,1].plot(df.loc['Colombia', anos])
axs[0,1].set_title('Colombia')

axs[1,0].plot(df.loc['Argentina', anos])
axs[1,0].set_title('Argentina')

axs[1,1].plot(df.loc['Peru', anos])
axs[1,1].set_title('Peru')

for ax in axs.flat:
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))

for ax in axs.flat:
    ax.set_xlabel('Ano')
    ax.set_ylabel('Número de imigrantes')

ymin = 0
ymax = 7000

for ax in axs.ravel():
    ax.set_ylim(ymin,ymax)



plt.show()

# %%
df.head(5)
# Out:
#                Continent           Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions    16    39
# Albania           Europe  Southern Europe   Developed regions     1     0
# Algeria           Africa  Northern Africa  Developing regions    80    67
# American Samoa   Oceania        Polynesia  Developing regions     0     1
# Andorra           Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...  2005  2006  2007  2008  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...  3436  3009  2652  2111
# Albania            0     0     0     0     1  ...  1223   856   702   560
# Algeria           71    69    63    44    69  ...  3626  4807  3623  4005
# American Samoa     0     0     0     0     0  ...     0     1     0     0
# Andorra            0     0     0     0     2  ...     0     1     1     0
#
# ...

# %%
america_sul_filtro = df['Region'] == 'South America'
df[america_sul_filtro]
# Out:
#                                                           Continent  \
# Country
# Argentina                           Latin America and the Caribbean
# Bolivia (Plurinational State of)    Latin America and the Caribbean
# Brazil                              Latin America and the Caribbean
# Chile                               Latin America and the Caribbean
# Colombia                            Latin America and the Caribbean
# Ecuador                             Latin America and the Caribbean
# Guyana                              Latin America and the Caribbean
# Paraguay                            Latin America and the Caribbean
# Peru                                Latin America and the Caribbean
# Suriname                            Latin America and the Caribbean
# Uruguay                             Latin America and the Caribbean
# Venezuela (Bolivarian Republic of)  Latin America and the Caribbean
#
# ...

# %%
america_sul_filtro_df2 = df.query('Region == "South America"')

# %%
america_sul_filtro_df2
# Out:
#                                                           Continent  \
# Country
# Argentina                           Latin America and the Caribbean
# Bolivia (Plurinational State of)    Latin America and the Caribbean
# Brazil                              Latin America and the Caribbean
# Chile                               Latin America and the Caribbean
# Colombia                            Latin America and the Caribbean
# Ecuador                             Latin America and the Caribbean
# Guyana                              Latin America and the Caribbean
# Paraguay                            Latin America and the Caribbean
# Peru                                Latin America and the Caribbean
# Suriname                            Latin America and the Caribbean
# Uruguay                             Latin America and the Caribbean
# Venezuela (Bolivarian Republic of)  Latin America and the Caribbean
#
# ...

# %%
fig, ax = plt.subplots(figsize=(14,5))

cores = ['royalblue', 'orange', 'forestgreen', 'orchid',
         'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal',
         'tomato']

#index -> paises
ax.barh(america_sul_filtro_df2.index, america_sul_filtro_df2['Total'], color=cores)
ax.set_title("Imigração da América do Sul para o Canadá\n1980 a 2013", fontsize=18)
ax.set_ylabel('')
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
plt.show()

# %%
america_sul_sorted = america_sul_filtro_df2.sort_values(by="Total", ascending=True)

# %%
fig, ax = plt.subplots(figsize=(14,5))

cores = ['royalblue', 'orange', 'forestgreen', 'orchid',
         'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal',
         'tomato']

#index -> paises
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
ax.set_title("Imigração da América do Sul para o Canadá\n1980 a 2013", fontsize=18)
ax.set_ylabel('')
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,5))

cores = []

for pais in america_sul_sorted.index:
    if pais == 'Brazil':
        cores.append('red')
    else:
        cores.append('silver')

#index -> paises
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
ax.set_title("América do Sul: Brasil foi o quarto pais com mais imigrantes\npara o Canadá\n1980 a 2013", fontsize=18, loc='left')
ax.set_ylabel('')
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)


#v+20 posiçao aonde vai ser adicionado
# i posição y do texto
#str(v) -> converte o tamanho de cada barra em texto
#ha alinhamento horizontal
#va -> alinhamento vertical

for i, v in enumerate(america_sul_sorted["Total"]):
    ax.text(v+20, i, str(v), color='black', fontsize=10, ha='left', va='center' )

ax.set_frame_on(False)
ax.get_xaxis().set_visible(False)
ax.tick_params(axis='both', which='both', length=0)


plt.show()
