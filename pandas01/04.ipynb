# %%
import pandas as pd
arquivo = "../data/kc_house_data.csv"
df = pd.read_csv(arquivo, sep=",")

# %%
colunas = [
    "id",
    "date",
    "view",
    "price"
]
df = pd.read_csv(arquivo, sep=",", usecols=colunas)

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
df.shape
# Out:
# (21613, 21)

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
#pra ver outliers etc;
pd.value_counts(df["bedrooms"])
# Out:
# C:\Users\brito\AppData\Local\Temp\ipykernel_18728\2756618619.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(df["bedrooms"])
# bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: count, dtype: int64

# %%
filtro = df["bedrooms"] == 3

df.loc[filtro]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 4      1954400510  20150218T000000  510000.0         3       2.00
# 6      1321400060  20140627T000000  257500.0         3       2.25
# 7      2008000270  20150115T000000  291850.0         3       1.50
# ...           ...              ...       ...       ...        ...
# 21603  7852140040  20140825T000000  507250.0         3       2.50
# 21604  9834201367  20150126T000000  429000.0         3       2.00
# 21607  2997800021  20150219T000000  475000.0         3       2.50
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21611   291310100  20150116T000000  400000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
## ele conta o numero de linhas

filtro2 = df["bedrooms"] == 4

df[filtro2].count()
# Out:
# id               6882
# date             6882
# price            6882
# bedrooms         6882
# bathrooms        6882
# sqft_living      6882
# sqft_lot         6882
# floors           6882
# waterfront       6882
# view             6882
# condition        6882
# grade            6882
# sqft_above       6881
# sqft_basement    6882
# yr_built         6882
# yr_renovated     6882
# zipcode          6882
# lat              6882
# long             6882
# sqft_living15    6882
# sqft_lot15       6882
# dtype: int64
