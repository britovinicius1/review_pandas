# %%
import pandas as pd

arquivo = "../data/kc_house_data.csv"
df = pd.read_csv(arquivo, sep=",", header=0)

# %%
##ele le só 5 linhas, ele carregou apenas 5 linhas diferentemente do head se nao vai ler tudo
dataset = pd.read_csv(arquivo, sep=",", nrows=5)
dataset
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650       1           0     0  ...      7        1180              0
# 1      7242       2           0     0  ...      7        2170            400
# 2     10000       1           0     0  ...      6         770              0
# 3      5000       1           0     0  ...      7        1050            910
# 4      8080       1           0     0  ...      8        1680              0
#
# ...

# %%
### chuncksize -> parametro que coloca em bloco de memoria a quantidade de linhas
#21k de linhas -> ex: da pra colocar em blocos a quantidade de linha q vc passou
dataset = pd.read_csv(arquivo, sep=",")
dataset
chunck = pd.read_csv(arquivo, sep=",", chunksize=10000)
type(chunck)
# Out:
# pandas.io.parsers.readers.TextFileReader

# %%
for parte in chunck:
    print(len(parte))
# Out:
# 10000
# 10000
# 1613

# %%
lista = []

for parte in chunck:
    lista.append(parte['bedrooms'] * 2)

dataset["dataset_siza"] = pd.concat(lista)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 6
#       2
#       3 for parte in chunck:
#       4     lista.append(parte['bedrooms'] * 2)
#       5
# ----> 6 dataset["dataset_siza"] = pd.concat(lista)
#
# File c:\Users\brito\review_pandas\.venv\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# ...
